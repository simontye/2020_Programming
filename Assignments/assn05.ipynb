# %%
### Assignment 05

# Write a Python script called 'parseGFF.py' that
# opens and reads the file, 'watermelon.gff'.
# Extract the gene name, store it in a list,
# then print an alphabetized list of the genes at the end.

# %%
input = open("watermelon.gff", "r")

for line in input:
    value = line.split("\t", 8) # Split by tab
    value = value[8] # Only save 9th column
    value = value.split(";", 5) # Split by semicolon
    value = value[0] # Only save 1st column
    value = value.split(" ", 1) # Split by space
    value = value[1] # Only save 2nd column
    print(value)
# Out:
# cox1 exon 1
# cox1
# cox1 exon 2
# similar to chloroplast LSC region from ndhC-trnV spacer to atpB-rbcL spacer
# trnM(CAT)-cp
# similar to chloroplast LSC region from psbD to psbC
# similar to chloroplast rbcL (LSC)
# similar to chloroplast IR region from rps12 to rps12-rps7 spacer
# rpl2 exon 1
# rpl2
# rpl2 exon 2
# rps19-1
# rps3 exon 1
# rps3
# rps3 exon 2
# rpl16
# atp6
# inverted repeat
# sdh3-1
# trnQ(TTG)-1
# trnG(GCC)-1
# trnM(CAT)-cp
# rps4
# nad6
# similar to chloroplast LSC region from trnG-trnfM spacer to trnfM-rps14 spacer
# atp8
# cox3
# sdh4
# nad2 exon 5
# nad2
# nad2 exon 4
# nad2
# nad2 exon 3
# trnY(GTA)
# trnN(GTT)-cp
# trnC(GCA)-2
# nad3
# rps12
# cox2 exon 1
# cox2
# cox2 exon 2
# similar to chloroplast psbC (LSC)
# nad1 exon 1
# atp6 fragment
# atp9 fragment
# similar to chloroplast rpoC2
# atp1
# trnC(GCA)-1
# trnE(TTC)
# trnH(GTG)-cp
# similar to chloroplast LSC region from rps14 to trnfM-rps14 spacer
# nad6 fragment
# ...

# %%
### GRAVEYARD OF FAILED ATTEMPTS

# Load modules
#import gffutils
#import os
#import sys
#import pandas
#from bioinfo_tools.parsers.gff import Gff3

# %%
# Change working directory
#os.getcwd()
#
#os.chdir("~/Users/simontye/Documents/Research/Courses/Programming)

# %%
# Load file
#file = gffutils.example_filename("/Users/simontye/Documents/Research/Courses/Programming/Assignments/watermelon.gff")

# Open, read, and print file
#print(open(file).read()) 

# Create a local sqlite3 file-based database
#db = gffutils.create_db(file, dbfn='test.db', force = True, keep_order = True, merge_strategy = 'merge', sort_attribute_values = True)

# Connect to database
#db = gffutils.FeatureDB('test.db', keep_order = True)
    
# Details about each gene are retained, but can be removed
# by adjusting last two lines of code

#for line in input:
#    value = line.split("\t", 8) # Split by tab and select 8th column
#    value[8]:
#        final.append(value[8])
#        x = final.strip("\n")
#        print(x)

#input.close()
#print(final)

#final2 = [remove[6:] for remove in final]

        #value = value[1].rstrip()
        #value = value.strip('\"')
        #if value in GeneList:
        #    print(value, "already found.")
        #else:
        #    GeneList.append(value)
        #    print(value, "added to list.")
            
            
# For loop to list gene names
#for genewilder in db:
#    print(genewilder)
# Out:
# cox1 exon 1
# cox1
# cox1 exon 2
# similar to chloroplast LSC region from ndhC-trnV spacer to atpB-rbcL spacer
# trnM(CAT)-cp
# similar to chloroplast LSC region from psbD to psbC
# similar to chloroplast rbcL (LSC)
# similar to chloroplast IR region from rps12 to rps12-rps7 spacer
# rpl2 exon 1
# rpl2
# rpl2 exon 2
# rps19-1
# rps3 exon 1
# rps3
# rps3 exon 2
# rpl16
# atp6
# inverted repeat
# sdh3-1
# trnQ(TTG)-1
# trnG(GCC)-1
# trnM(CAT)-cp
# rps4
# nad6
# similar to chloroplast LSC region from trnG-trnfM spacer to trnfM-rps14 spacer
# atp8
# cox3
# sdh4
# nad2 exon 5
# nad2
# nad2 exon 4
# nad2
# nad2 exon 3
# trnY(GTA)
# trnN(GTT)-cp
# trnC(GCA)-2
# nad3
# rps12
# cox2 exon 1
# cox2
# cox2 exon 2
# similar to chloroplast psbC (LSC)
# nad1 exon 1
# atp6 fragment
# atp9 fragment
# similar to chloroplast rpoC2
# atp1
# trnC(GCA)-1
# trnE(TTC)
# trnH(GTG)-cp
# similar to chloroplast LSC region from rps14 to trnfM-rps14 spacer
# nad6 fragment
# ...

# %%
# Install BCBio pack (bash)
#git clone git://github.com/chapmanb/bcbb.git
#cd bcbb/gff
#python setup.py build
#sudo python setup.py install

# Load modules
#import pprint
#from BCBio import GFFExaminer

#in_file = "watermelon.gff"
#examiner = GFFExaminer()
#in_handle = open(in_file)
#pprint.pprint(examiner.parent_child_map(in_handle))
#in_handle.close()

#########################

#from Bio import SeqIO
#
#for seq_record in SeqIO.parse("watermelon.gff", "gff"): print(seq_record.id)
#print(repr(seq_record.seq))
#print(len(seq_record))

#########################


## Open watermelon.gff
#watermelon = open("watermelon.gff", "r")
#water = watermelon.read()
#print(water)
#
# Create empty list
#genes = []

# Extract gene names from watermelon and store in a list
#for coronavirus in watermelon:
#    genes.append(coronavirus.rstrip())
#
## For loop
#for whatever in genes:
#    print(whatever)
#    
# Close the file
#watermelon.close()
#
# watermelon = open(watermelon, "r")
# water = watermelon.read()
# print(water)
#
# Print alphabetized list of gene names
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-245-8003140a7cfa> in <module>
#      14 # Load modules
#      15 import pprint
# ---> 16 from BCBio import GFFExaminer
#      17
#      18 #in_file = "watermelon.gff"
#
# ModuleNotFoundError: No module named 'BCBio'

# %%
#gff_parser = Gff3()
#with open("/Users/simontye/Documents/Research/Courses/Programming/Assignments/watermelon.gff", "r") as fh:
#    for gene in gff_parser.read(fh):
#        print(gene)
        
## Test
#for line in sys.stdin:
#    convertedLine = ""
#    chomped_line = line.rstrip(os.linesep)
#    if chomped_line.startswith('##'):
#        pass
#    elif chomped_line.startswith('track'):
#        pass
#    else:
#        elems = chomped_line.split('\t')
#        cols = dict()
#        try:
#            cols['seqname'] = elems[0].lstrip(' ')
#            cols['source'] = elems[1]
#            cols['feature'] = elems[2]
#            cols['start'] = int(elems[3])
#            cols['end'] = int(elems[4])
#            cols['score'] = elems[5]
#            cols['strand'] = elems[6]
#            cols['frame'] = elems[7]
#            cols['attributes'] = elems[8].rstrip(' ')
#        except IndexError as ie:
#            sys.stderr.write("[%s] - Error: Input appears to be missing GTF-specific fields (check that your input data is GTF-formatted)\n" % (sys.argv[0]))
#            sys.exit(os.EX_DATAERR)
#        try:
#            cols['comments'] = elems[9]
#        except IndexError as ie:
#            cols['comments'] = None
#        attributes = dict(item.strip().split(' ') for item in cols['attributes'].split(';') if item):
#            for line in file:
#                print(attributes])
#

# %%
#for line in input:
#    value = line.split("\t", 8) # Split by tab and select 8th column
#    value[8]:
#        final.append(value[8])
#        x = final.strip("\n")
#        print(x)

#input.close()
#print(final)

#final2 = [remove[6:] for remove in final]

        #value = value[1].rstrip()
        #value = value.strip('\"')
        #if value in GeneList:
        #    print(value, "already found.")
        #else:
        #    GeneList.append(value)
        #    print(value, "added to list.")
            
            
# For loop to list gene names
#for genewilder in db:
#    print(genewilder)
